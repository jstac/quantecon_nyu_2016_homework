# %% [markdown]
# # Homework set 9 Comp Econ
#
# **Author** Pierre Mabille
#
# **NYU ID** N10017621
#
# **Date** April 15, 2016

# %% [markdown]
# ### Exercise 1
#
# Proving the statement is equivalent to proving that for every $A \in \mathcal{M}(n\times n)$ we have $$||A||^2 = \rho(A'A).$$
#
# First note that $||A||^2 = \left(\sup_{x\in \mathbb{R}^n \setminus \{0\}} \frac{||Ax||}{||x||} \right)^2 = \left(\sup_{x\in \mathbb{R}^n \setminus \{0\}, ||x||=1} ||Ax|| \right)^2$, where the second equality is w.l.o.g. (it should be obvious from the context when the spectral norm and vector norms like the Euclidean norms are used). The function $x \mapsto ||Ax||$ is continuous by continuity of a linear operator and of the norm, and the set $\left\lbrace x\in \mathbb{R}^n \setminus \{0\}, ||x||=1 \right\rbrace$ is compact, so by the theorem of the maximum the maximum is attained, and we can replace the sup by a max, $$\max_{x\in \mathbb{R}^n \setminus \{0\}, ||x||=1} ||Ax|| = \max_{x\in \mathbb{R}^n \setminus \{0\}, ||x||=1} \left[x'(A'A)x \right]^{1/2} = \max_{x\in \mathbb{R}^n \setminus \{0\}, \sum_{i=1}^nx_i^2=1} \left[x'(A'A)x \right].$$
#
# Then we solve the maximization problem using the Lagrange method for constrained optimization: \begin{eqnarray*}
# && \mathcal{L} = x'(A'A)x  + \lambda \left[1-\sum_{i=1}^nx_i^2\right] \\
# & \Rightarrow & \frac{\partial \mathcal{L}}{x} =  (A'A)x=\lambda x
# \end{eqnarray*}
# To conclude, note that by definition of the spectral radius, $$\rho(A'A)=\max\left\lbrace |\lambda|: \exists x\in \mathbb{R}\setminus \{0\}, A'Ax = \lambda x \right\rbrace.$$
# Note that the FOC implies $x'(A'A)x=\lambda x'x = \lambda ||x||^2 = \lambda$, since $||x||=1$.
#
# So $\left(\max_x \frac{||Ax||}{||x||}\right)^2 = \lambda = |\lambda|$, where the last equality follows from $A'A$ being positive semi-definitive (quadratic form), and thus with non-negative eigenvalues. This proves the claim.

# %% [markdown]
# ### Exercise 2
#
#
# We have $\rho(A)<1$. By Gelfand's formula, $\lim_{k\to\infty} ||A^k||^{1/k} = \rho(A)$, i.e. $\forall \epsilon >0$ $\exists K \in \mathbb{R}$ s.t. $\forall k \geq K$, $$\left| ||A^k||^{1/k}-\rho(A) \right| \leq \epsilon. $$
#
# This implies $||A^k||^{1/k}-\rho(A) \leq \epsilon$, i.e. $||A^k||^{1/k} \leq \rho(A)+\epsilon$, i.e. $||A^k|| \leq (\rho(A)+\epsilon)^k$. Denote $r=\rho(A)+\epsilon < 1$ because $\epsilon$ can be chosen arbitrarily small and $\rho(A)<1$. Also denote $C=1\in \mathbb{N}$. Thus we have an upper bound for the high end of the sequence of spectral norms.
#
# Now let's consider the low end of this sequence. For any $k'<K$, we have $$||A^{k'}|| \leq \max_{k''=1,...,K}||A^{k''}||. $$
#
# Now, $r<1$ implies that for any such $k'$, $||A^{k'}|| \leq \max_{k''=1,...,K}||A^{k''}|| \leq \max_{k''=1,...,K}||A^{k''}|| \frac{r^{k'}}{r^K}$. That is, $||A^{k'}|| \leq \frac{\max_{k''=1,...,K}||A^{k''}||}{r^K}r^{k'}$. Thus we have also bounded the lower end of the sequence.
#
# It suffices to note that the bound on the higher end of the sequence (for $k\geq K$) implies that $C \equiv \frac{\max_{k''=1,...,K}||A^{k''}||}{r^K} \geq 1$, to conclude that we can also bound the high-end of the sequence using $C$.
#
# This completes the proof of the statement that if $\rho(A)<1$, there exists $r=\rho(A)+\epsilon<1$ and $C=\frac{\max_{k''=1,...,K}||A^{k''}||}{r^K}$ such that $||A^k|| \leq r^k C$ (if we want $C\in \mathbb{N}$ we can take the smallest integer greater than $C$). (Note that $r$ and $C$ depend on each other, through $\epsilon$ and $K$).
#
# This last statement implies that $\sum_{k=0}^\infty ||A^k|| \leq C\sum_{k=0}^\infty r^k = \frac{C}{1-r} < \infty$.

# %% [markdown]
# ### Exercise 3
#
# The matrix $A$ is diagonalizable, so there exists a matrix of eigenvector columns $Q \in \mathcal{M}(n\times n)$ and a diagonal matrix of eigenvalues $\Lambda \in \mathcal{M}(n\times n)$, such that $A=Q^{-1}\Lambda Q$.
#
# This implies that $A^k=Q^{-1}\Lambda^kQ$.
#
# Now by the submultiplicative property of the spectral norm we have $||A^k|| \leq  ||Q^{-1}||.||\Lambda^k||.||Q||$.\\
# We now have the following relations $||\Lambda^k|| = \sqrt{\rho(\Lambda^{2k})}=\sqrt{\rho(\Lambda)^{2k}}=\rho(\Lambda)^k=\rho(A)^k \to 0$ as $k\to \infty$.
#
# The 1st equality is from exercise 1, the 2nd is from the fact that $\Lambda$ is a diagonal matrix, and the last one from the definition of diagonalization.
#
# To conclude we use the continuity of the application $\Lambda \mapsto Q^{-1}\Lambda^kQ$ to take the limit inside: $$ 0 \leq \lim_{k\to\infty}||A^k|| \leq Q^{-1}\lim_{k\to\infty}\Lambda^kQ=0.$$

# %% [markdown]
# ### Exercise 4
#
# Take a sequence of matrices $\left\lbrace M_k \right\rbrace \in \mathcal{M}(n\times n)$ such that $\forall z \in \mathbb{R}^n \setminus \{0\}$ we have $z'M_kz\geq 0$ (positive semi-definiteness), and $\lim M_k = M$ (in the spectral norm sense). We want to show that $M$ is positive semi-definite too, i.e. $\forall z \in \mathbb{R}^n \setminus \{0\}$ we have $z'Mz\geq 0$. It suffices to show that $\lim z' M_kz=z'Mz$.
#
# Note that this is equivalent to showing that the operator $f_z:N\in \mathcal{M}(n\times n) \mapsto z'Nz$ defined for any $z\in \mathbb{R}^n \setminus \{0\}$ is continuous.
#
# That is, we want to show that for any $\epsilon>0$, there exists $K\in \mathbb{R}$ such that for all $k \geq K$, and for all $z \in \mathbb{R}^n \setminus \{0\}$, we have $|z'M_kz-z'Mz|=|z'(M_k-M)z|< \epsilon$. \\
# Take any such $z$. By the Cauchy-Schwartz inequality, we have $$0\leq |z'(M_k-M)z| \leq ||z'||.||(M_k-M)z|| \leq ||z'||.||M_k-M||.||z|| = ||z||^2.||M_k-M||,$$
#
# where the second inequality follows from the definition of the spectral norm, and the last equality from the property of the norm that the norm of a vector and of its transpose are the same.
#
# We conclude the proof by using the definition of convergence under the spectral norm. Taking limits as $k\to \infty$ in the inequality implies $\lim |z'(M_k-M)z|=0$, i.e. $\lim z'M_kz=z'Mz \geq 0$. QED.

# %% [markdown]
# ### Exercise 5
#
# Take $M, A\in \mathcal{M}(n\times n)$, with $\rho(A)<1$. Let $X$ be the unique solution to the Lyapunov equation $X=AXA'+M$.
#
# (1) Suppose $M$ is symmetric, i.e. $M=M'$. Taking transposes in the Lyapunov equation implies $X'=AX'A'+M'=AX'A'+M$. But $X$ is the unique solution, so $X'=X$.
#
# (2) Suppose $M$ is positive semi-definite, i.e. $\forall z\in \mathbb{R}^n \setminus \{0\}$, $z'Mz\geq 0$. This defines a "quadratic" operator $X \mapsto z'Xz$. Apply it in the Lyapunov equation, which implies the following: $$z'Xz=z'(AXA'+M)z= z'(AXA')z+z'Mz \Rightarrow z'Xz-z'(AXA')z = z'Mz \geq 0$$
# $$i.e. \hspace{3mm} z'Xz\geq z'AXA'z = (A'z)'X(A'z)$$
# Thie defines a new "quadratic" operator $X\mapsto (A'z)'X(A'z)$. Apply it again in the Lyapunov equation, to obtain in a similar fashion that $$ (A'z)'X(A'z) \geq (A'z)'AXA'(A'z) = z'A^2X(A^2)'z$$
# And so on and so forth, iterate on the Lypanunov equation using the operators implicitly defined at every new iteration. We have seen in exercise 4 that this type of operator is continuous, so we can take the limit in the inequality. It then suffices to show that $\lim_{k\to\infty}z'A^kX(A^k)'z=0$. That follows from application of Gelfand's formula. Te fact that $||A^k||^{1/k} \to \rho(A)<1$ implies that $\lim ||A^k||^{1/k}=0$. By continuity and non-negativity of the norm, this is only possible if $\lim A^k=0$. Finally the result is obtained by using the continuity of our "quadratic operator". \\
#
# (3) Suppose $M$ is positive definite. It is unsure we can apply the same reasoning as in the positive semi-definite case, since strict inequalities are unlikely to be preserved at the limit.
#
# I therefore use another proof. I use the fact i) that the Lyapunov operator defined by $LX\equiv AXA'+M$ is a contraction, and ii) The corollary to the contraction mapping theorem: if $S$ is a closed subset of $\mathcal{M}(n\times n)$ and $L(S) \subseteq S$, then the fixed point $X\in S$. And that if $L(S) \subseteq S' \subset S$, then $X\in S'$. [This corollary is a classical result in macro, I don't re-prove it; the proof is e.g. in Stokey-Lucas-Prescott].
#
# First, note that the set of positive semi-definite matrices is a closed subset of $\mathcal{n\times n}$. This follows from the fact that it can be defined as the intersection $\cap_{z\in \mathbb{R}^n \setminus \{0\}}f_z^{-1}\left( [0,\infty)\right)$, where $f_z$ is the quadratic form defined in exercise 4. $[0,\infty)$ is closed, and such an intersection of closed sets is closed.\\
#
# Then use the Lyapunov equation to show that the Lyapnuov operator $L$ maps positive semi-definite $X$  (if $M$ is positive definite, then in particular it is positive semi-definite) to positive definite $X$. This readily follows from the same reasoning as in my first proof: $$z'Xz=z'(AXA'+M)z= z'(AXA')z+z'Mz  > 0,$$ because $z'Mz>0$. By the corollary to the contraction mapping theorem, this implies that the fixed point $X$ is positive definite. QED.

# %% [markdown]
# ### Exercise 6
#
# Define the model parameters used for testing the conmputations.

# %%
A = [.8 -.1;
-.1 .8]
C = eye(2)
D = eye(2)
beta = .9
# Out:
# 0.9

# %% [markdown]
# Define a function taking as argument the primitives of the problem, which returns $P$ and $\delta$. It also tests the stability condition in the Lyapunv equation.
#
# The price function is then defined as $$p^*(x) = x'P^*x + \delta^*.$$
#
# It is computed for the primitives given above and $u_t \sim \mathcal(N)(0,1)$ iid, and prices are simulated over a $T=100$ horizon and plotted.

# %%
function compute_price(beta::Float64, A::Array{Float64,2}, C::Array{Float64,2}, D::Array{Float64,2})
    # solve the discrete Lyapunov equation
    M = beta*A'*D*A
    Lambda = sqrt(beta)*A'
    if maximum(abs(eig(Lambda)[1])) >= 1/sqrt(beta) # stability condition rho(Lambda)<1/sqrt(beta)
        error("ARGUMENT ERROR: A, beta: Stability condition rho(A) < 1/sqrt(beta) violated.")
    else
        P0 = ones(2,2)*.9
        distance = 1
        conv_crit = 1e-3
        maxit = 100
        iter = 0
        while distance > conv_crit || iter > maxit
            P1 = Lambda*P0*Lambda' + M
            distance = norm(P1-P0, Inf)
            P0 = deepcopy(P1)
            #     println("distance"); println(distance) # print distance to check convergence
            iter = iter +1
        end
        P = P0
        delta = beta/(1-beta) * trace(C'*(D+P)*C)
    end
    return P, delta
end
# Out:
# compute_price (generic function with 1 method)

# %%
# %matplotlib inline
using PyPlot

P, delta = compute_price(beta, A, C, D)

T = 100
# state x process N(0,1)
w = randn(2, T+1)
x = zeros(2, T+1)
for t = 1:T
    x[:,t+1] = A*x[:,t] + C*w[:,t+1]
end
# simulate prices 
p = Array(Float64,T+1)
for t = 1:T+1
    p[t] = (x[:,t]'*P*x[:,t])[1] + delta
end

fig, ax = subplots()
ax[:plot](collect(1:T), p[2:T+1], linewidth=2, alpha=0.6)
ax[:set_xlabel]("t")
ax[:set_ylabel]("pt")
ax[:legend](loc="upper right")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000024C3C748>)

# %% [markdown]
# Now let's make the contour plot. For that use the QuantEcon package. I obtain the same graph as in the problem set.

# %%
using QuantEcon

# == Set up grid for plotting == #
x_grid = linspace(-10,10, 200)
y_grid = linspace(-10, 10, 200)
X, Y = meshgrid(x_grid, y_grid)

function gen_prices(P, delta)
    price = Array(Float64, length(x_grid), length(y_grid))
    for i in 1:length(x_grid)
        for j in 1:length(y_grid)
            state = [x_grid[i];y_grid[j]]
            price[i,j] = (state'*P*state + delta)[1]
        end
    end
    return price
end

# helper function to prepare axis
function prep_ax()
    fig, ax = subplots()
    ax[:xaxis][:grid](true, zorder=0)
    ax[:yaxis][:grid](true, zorder=0)
    return ax
end

function plot1()
    ax = prep_ax()
    Z = gen_prices(P, delta)
    ax[:contourf](X, Y, Z, 8, alpha=0.6, cmap=ColorMap("jet"))
    cs = ax[:contour](X, Y, Z, 8, colors="black")
    ax[:clabel](cs, inline=1, fontsize=10)
end
plot1()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000024C39F28>)
# 8-element Array{Any,1}:
#  PyObject <matplotlib.text.Text object at 0x000000001887FC88>
#  PyObject <matplotlib.text.Text object at 0x0000000026DBAE80>
#  PyObject <matplotlib.text.Text object at 0x0000000026DBAF98>
#  PyObject <matplotlib.text.Text object at 0x00000000188634A8>
#  PyObject <matplotlib.text.Text object at 0x000000001888CE10>
#  PyObject <matplotlib.text.Text object at 0x000000001888CDD8>
#  PyObject <matplotlib.text.Text object at 0x0000000018821588>
#  PyObject <matplotlib.text.Text object at 0x000000001889AE48>
